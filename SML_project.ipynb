# %% [markdown]
# <a href="https://colab.research.google.com/github/himabindhu717/Sml_2303A52050/blob/main/SML_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv('/content/drive/MyDrive/archive (2).zip',usecols=(['Confirmed','Deaths']))
data.head()
#print(data)
data.shape
#data.info()
data.describe()
data.skew()
data.kurt()
# Out:
# Confirmed   -0.284262
# Deaths      -1.311584
# dtype: float64

# %%
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
plt.plot(data, color='r')
plt.show()

# %%
x=data.drop('Deaths',axis=1)
y=data.Deaths
from sklearn import linear_model
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (150, 1)
# (38, 1)
# (150,)
# (38,)

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
reg.fit(x_train,y_train)
reg.intercept_
reg.coef_
# Out:
# array([0.04450504])

# %%
y_pred=reg.predict(x_test)
y_pred
# Out:
# array([208132.12228909,  37383.07287492, 497760.3123181 ,  53867.47163099,
#        269563.22625455, 121046.40115341,  34480.58786254, 218739.14132485,
#        475770.37342769,  32970.5764547 ,  32826.42463915, 242581.64689458,
#        459327.72039653,  78490.41753341, 211952.70171428, 174453.38042321,
#         36408.36805476, 161369.07750068, 334383.52231942,  88964.05497262,
#         41541.84607794, 307983.40127073,  42413.52173694, 157589.17567951,
#        578909.28401381, 417566.10718586, 250802.08330941, 222459.7179314 ,
#        766160.75672412,  36205.55860015,  32790.42006404, 273805.71343258,
#        534363.70270488,  49774.96642839,  37203.36153463,  35936.79268038,
#        625897.88033085, 345429.71706247])

# %%
y_test
# Out:
# 107    276304
# 45       3553
# 160    511210
# 63      21793
# 122    343385
# 83     132996
# 18        906
# 110    287608
# 157    499268
# 7         133
# 5          82
# 116    316366
# 155    489955
# 71      56334
# 108    280569
# 98     228742
# 37       2867
# 94     206979
# 135    396994
# 74      73181
# 55       7948
# 130    373606
# 56       8845
# 93     201401
# 169    554831
# 149    460973
# 118    324441
# 111    293155
# 187    654036
# 33       2627
# 4          56
# 123    346525
# 164    530705
# 61      16748
# 44       3454
# 26       1868
# 174    578468
# 137    403617
# Name: Deaths, dtype: int64

# %%
from sklearn import metrics
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error:',metrics.mean_squared_error(y_test,y_pred))
# Out:
# Mean Absolute Error: 44250.85586923366
# Mean Squared Error: 2461414698.0222845
